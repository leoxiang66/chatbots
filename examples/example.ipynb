# %% [markdown]
# <a href="https://colab.research.google.com/github/leoxiang66/chatbots/blob/main/examples/example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/leoxiang66/chatbots.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/leoxiang66/chatbots.git to /tmp/pip-req-build-91qsfu__
#   Running command git clone -q https://github.com/leoxiang66/chatbots.git /tmp/pip-req-build-91qsfu__
# ...

# %%
from chatbots import Blenderbot

# %%
bot = Blenderbot()

# %%
usr = input()
while usr != 'exit':
    print(bot.reply(usr))
    usr = input()
# Out:
# hi
# /usr/local/lib/python3.7/dist-packages/transformers/generation_utils.py:1207: UserWarning: Neither `max_length` nor `max_new_tokens` have been set, `max_length` will default to 60 (`self.config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   UserWarning,
# Hello! I am in such a good mood since I got my Hi-5 figures, I didn't know what to do with them.
# that's cool
# I know. My girlfriend got them for me for my birthday. I love her so much.
# congratulations!
# Thank you! I think the most important thing is to love your girlfriend, and not everything in life comes together.
# exit
